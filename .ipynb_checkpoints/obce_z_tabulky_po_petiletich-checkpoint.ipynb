# %%
import pandas

file_obce = 'sldb2021_vek5_pohlavi.csv'

df_obce = pandas.read_csv(file_obce, encoding='utf-8')

df_obce.head()
# Out:
#        idhod  hodnota  ukaz_kod  vek_cis       vek_kod  pohlavi_cis  \
# 0  947108883     1817      3162      NaN           NaN          NaN
# 1  947084833      909      3162      NaN           NaN        102.0
# 2  947119976      908      3162      NaN           NaN        102.0
# 3  964961283       93      3162   1035.0  1.100000e+09          NaN
# 4  964734134       60      3162   1035.0  1.100000e+09        102.0
#
#    pohlavi_kod  uzemi_cis  uzemi_kod  sldb_rok  sldb_datum  \
# 0          NaN         43     500011      2021  2021-03-26
# 1          1.0         43     500011      2021  2021-03-26
# 2          2.0         43     500011      2021  2021-03-26
# 3          NaN         43     500011      2021  2021-03-26
# 4          1.0         43     500011      2021  2021-03-26
#
#                             ukaz_txt     vek_txt pohlavi_txt  \
# 0  Počet obyvatel s obvyklým pobytem         NaN         NaN
# 1  Počet obyvatel s obvyklým pobytem         NaN         muž
# 2  Počet obyvatel s obvyklým pobytem         NaN        žena
# 3  Počet obyvatel s obvyklým pobytem  0 - 4 roky         NaN
# 4  Počet obyvatel s obvyklým pobytem  0 - 4 roky         muž
#
#                   uzemi_txt
# 0  Želechovice nad Dřevnicí
# 1  Želechovice nad Dřevnicí
# 2  Želechovice nad Dřevnicí
# 3  Želechovice nad Dřevnicí
# 4  Želechovice nad Dřevnicí

# %% [markdown]
# potřebuju:
# 0: idhod,
# 1: hodnota (= počet osob),
# 4: vek_kod (= kod pro kat. 15-19)
# 6: pohlavi_kod (= NaN >> M+F dohromady)
# uzemi_kod
# vek_txt
# pohlavi_txt
# uzemi_txt
