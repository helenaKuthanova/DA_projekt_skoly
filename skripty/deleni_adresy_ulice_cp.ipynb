# %%
import pandas as pd
import re

# %%
file = 'OSM/skoly_vsechny_kraje_praha.csv'
sep = ';'
final = 'OSM/skoly_vsechny_kraje_praha_gps.csv'

# %%
df = pd.read_csv(file, sep=sep)
df
# Out:
#      Column1         id          nazev  typ               adresa1  \
# 0          0   60076135  Střední škola  C00  Fráni Šrámka 1193/23
# 1          1   60076101  Střední škola  C00      Jírovcova 1788/8
# 2          2   60076062  Střední škola  C00           Čihovice 13
# 3          3   62534408  Střední škola  C00            Školní 995
# 4          4   60076046  Střední škola  C00     Husova tř. 1849/1
# ..       ...        ...            ...  ...                   ...
# 800     1013  130002542  Střední škola  C00         Vlčnovská 688
# 801     1014  150008023  Střední škola  C00      Na Záhonech 1177
# 802     1015  150067241  Střední škola  C00               č.ev. 1
# 803     1016  200000055  Střední škola  C00           Zlínská 991
# 804     1017  181044684  Střední škola  C00           Filmová 174
#
#                               adresa2                  adresa3      PSC  \
# 0                  České Budějovice 3  370 01 České Budějovice  37001.0
# ...

# %%
len(df)
# Out:
# 805

# %% [markdown]
#         pattern = r' \d\d '
#         list_obec = re.split(pattern, adresa3)
#         obec = list_obec[-1]
#
#         #izoluji psč
#         pattern2 = r' [A-ZÁČĎŘŠŤÚŽ]'
#         list_obec = re.split(pattern2, adresa3)
#         PSC = list_obec[0]
#
#         merged.loc[3, 'okres'] = 'Blansko' (merged je moje spojená tabulka, trojka je index řádku, okres je sloupec)

# %%
pattern1 = r' [1-9]'
pattern2 = r'[a-záéíóůúčřžšěťďň.A-Z] '

for i in df.index:
    adresa = df['adresa1'][i]
    list_ulice = re.split(pattern1, adresa)
    nazev_ulice = list_ulice[0]
    list_cislo = re.split(pattern2, adresa)
    cislo_popisne = list_cislo[-1]
    df.loc[i, 'nazev_ulice'] = nazev_ulice
    df.loc[i, 'cislo_popisne'] = cislo_popisne
df
# Out:
#      Column1         id          nazev  typ                          adresa1  \
# 0          0   60076135  Střední škola  C00             Fráni Šrámka 1193/23
# 1          1   60076101  Střední škola  C00                 Jírovcova 1788/8
# 2          2   60076062  Střední škola  C00                      Čihovice 13
# 3          3   62534408  Střední škola  C00                       Školní 995
# 4          4   60076046  Střední škola  C00                Husova tř. 1849/1
# 5          6     666122  Střední škola  C00                  Jirsíkova 420/5
# 6          7   45019517  Střední škola  C00               Třebízského 1010/9
# 7          8   60074302  Střední škola  C00             Pražská tř. 2532/54A
# 8          9   60074281  Střední škola  C00                Žižkova tř. 250/4
# 9         10   60075775  Střední škola  C00                     Česká 142/64
# 10        11  110150309  Střední škola  C00           Rudolfovská tř. 458/92
# ...

# %% [markdown]
# ### Problémy
# * 139 Sedlec 101, okr. Břeclav - bez ulice
# * 150 ul = nám. 17. listopadu)
# * 162 Mariánské lázně 569 - bez ulice
# * 271 Petrovice u Karviné 570 - bez ulice
# * 449 ul = sady 5. května
# * 528 ul = náměstí 25. března
# * 758 Vladislav 203 (Vysočina) - bez ulice
# * 802 Velehrad 1 - bez ulice

# %%
pd.set_option('display.max_rows', None)

# %%
df.loc[139, 'nazev_ulice'] = 'Sedlec'
df.loc[150, 'nazev_ulice'] = 'nám. 17. listopadu'
df.loc[162, 'nazev_ulice'] = 'Mariánské lázně'
df.loc[271, 'nazev_ulice'] = 'Petrovice u Karviné'
df.loc[449, 'nazev_ulice'] = 'sady 5. května'
df.loc[528, 'nazev_ulice'] = 'náměstí 25. března'
df.loc[758, 'nazev_ulice'] = 'Vladislav'
df.loc[802, 'nazev_ulice'] = 'Velehrad'

# %%
df
# Out:
#      Column1         id          nazev  typ                          adresa1  \
# 0          0   60076135  Střední škola  C00             Fráni Šrámka 1193/23
# 1          1   60076101  Střední škola  C00                 Jírovcova 1788/8
# 2          2   60076062  Střední škola  C00                      Čihovice 13
# 3          3   62534408  Střední škola  C00                       Školní 995
# 4          4   60076046  Střední škola  C00                Husova tř. 1849/1
# 5          6     666122  Střední škola  C00                  Jirsíkova 420/5
# 6          7   45019517  Střední škola  C00               Třebízského 1010/9
# 7          8   60074302  Střední škola  C00             Pražská tř. 2532/54A
# 8          9   60074281  Střední škola  C00                Žižkova tř. 250/4
# 9         10   60075775  Střední škola  C00                     Česká 142/64
# 10        11  110150309  Střední škola  C00           Rudolfovská tř. 458/92
# ...

# %%
df.to_csv(final, encoding='utf-8', sep=';')
