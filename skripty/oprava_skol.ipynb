# %%
import pandas as pd

# %%
df = pd.read_csv('skoly_vsechny_kraje_praha.csv', encoding='utf-8')
df
# Out:
#      Unnamed: 0.1  Unnamed: 0         id          nazev  typ  \
# 0               0           0   60076135  Střední škola  C00
# 1               1           1   60076101  Střední škola  C00
# 2               2           2   60076062  Střední škola  C00
# 3               3           3   62534408  Střední škola  C00
# 4               4           4   60076046  Střední škola  C00
# ..            ...         ...        ...            ...  ...
# 865          1120        1120  130002542  Střední škola  C00
# 866          1121        1121  150008023  Střední škola  C00
# 867          1122        1122  150067241  Střední škola  C00
# 868          1123        1123  200000055  Střední škola  C00
# 869          1124        1124  181044684  Střední škola  C00
#
#                   adresa1                           adresa2  \
# 0    Fráni Šrámka 1193/23                České Budějovice 3
# 1        Jírovcova 1788/8                České Budějovice 3
# ...

# %%
df[df['obor_delka'] != 40]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, id, nazev, typ, adresa1, adresa2, adresa3, PSC, obec, kraj, obor_kod, obor_nazev, obor_forma, obor_delka, obor_kapacita, okres, kod_okresu_a, kod_okresu_b]
# Index: []

# %%
df['obor_delka'].unique()
# Out:
# array([40], dtype=int64)

# %%
df['obor_forma'].unique()
# Out:
# array([10], dtype=int64)

# %%
df_skoly_ctyrlete_prezencni = df[df['obor_forma'] == 10]

# %%
df_skoly_ctyrlete_prezencni
# Out:
#      Unnamed: 0.1  Unnamed: 0         id          nazev  typ  \
# 0               0           0   60076135  Střední škola  C00
# 1               1           1   60076101  Střední škola  C00
# 2               2           2   60076062  Střední škola  C00
# 3               3           3   62534408  Střední škola  C00
# 4               4           4   60076046  Střední škola  C00
# ..            ...         ...        ...            ...  ...
# 865          1120        1120  130002542  Střední škola  C00
# 866          1121        1121  150008023  Střední škola  C00
# 867          1122        1122  150067241  Střední škola  C00
# 868          1123        1123  200000055  Střední škola  C00
# 869          1124        1124  181044684  Střední škola  C00
#
#                   adresa1                           adresa2  \
# 0    Fráni Šrámka 1193/23                České Budějovice 3
# 1        Jírovcova 1788/8                České Budějovice 3
# ...

# %%
df_skoly_ctyrlete_prezencni['obor_forma'].unique()
# Out:
# array([10], dtype=int64)

# %%
df_skoly_ctyrlete_prezencni = df_skoly_ctyrlete_prezencni[df_skoly_ctyrlete_prezencni['obor_delka'] == 40]

# %%
df_skoly_ctyrlete_prezencni
# Out:
#      Unnamed: 0.1  Unnamed: 0         id          nazev  typ  \
# 0               0           0   60076135  Střední škola  C00
# 1               1           1   60076101  Střední škola  C00
# 2               2           2   60076062  Střední škola  C00
# 3               3           3   62534408  Střední škola  C00
# 4               4           4   60076046  Střední škola  C00
# ..            ...         ...        ...            ...  ...
# 865          1120        1120  130002542  Střední škola  C00
# 866          1121        1121  150008023  Střední škola  C00
# 867          1122        1122  150067241  Střední škola  C00
# 868          1123        1123  200000055  Střední škola  C00
# 869          1124        1124  181044684  Střední škola  C00
#
#                   adresa1                           adresa2  \
# 0    Fráni Šrámka 1193/23                České Budějovice 3
# 1        Jírovcova 1788/8                České Budějovice 3
# ...

# %%
df_skoly_ctyrlete_prezencni['obor_delka'].unique()
# Out:
# array([40], dtype=int64)

# %%
df_skoly_ctyrlete_prezencni.to_csv('skoly_vsechny_kraje_praha.csv', encoding='utf-8', index=None)
